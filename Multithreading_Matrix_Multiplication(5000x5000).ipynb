# %% [markdown]
# <a href="https://colab.research.google.com/github/ashnaarora251/Multithreading-assignment/blob/main/Multithreading_Matrix_Multiplication(5000x5000).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time
import multiprocessing
import pandas as pd
import matplotlib.pyplot as plt
import psutil

# %%
# Function to perform matrix multiplication with a constant matrix
def matrix_multiply(constant_matrix, num_threads):
    # Generate random matrix of size 1000x1000
    random_matrix = np.random.rand(5000, 5000)
    # Start timing
    start_time = time.time()
    # Multiply random matrix with constant matrix using the specified number of threads
    np.dot(random_matrix, constant_matrix)
    # End timing
    end_time = time.time()
    # Calculate time taken
    time_taken = end_time - start_time
    cpu_usage = psutil.cpu_percent()
    print(f"CPU usage: {cpu_usage}%")
    return time_taken

# %%
# Generate constant matrix of size 1000x1000
constant_matrix = np.random.rand(5000, 5000)

# Define the number of threads
num_threads = [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Perform matrix multiplication with different number of threads
time_taken_list = []
for t in num_threads:
    time_taken = matrix_multiply(constant_matrix, t)
    time_taken_list.append(time_taken)

result_df = pd.DataFrame({'Threads': num_threads, 'Time Taken (Sec)': time_taken_list})
# Out:
# CPU usage: 55.9%
# CPU usage: 98.8%
# CPU usage: 100.0%
# CPU usage: 98.8%
# CPU usage: 98.7%
# CPU usage: 100.0%
# CPU usage: 98.7%
# CPU usage: 98.8%

# %%
# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(num_threads, time_taken_list, marker='o')
plt.title('Matrix Multiplication Time vs. Number of Threads')
plt.xlabel('Number of Threads')
plt.ylabel('Time Taken (Seconds)')
plt.grid(True)
plt.show()

# %%
# Display the result table
print("\nResult Table:")
print(result_df)
# Out:
# Result Table:
#    Threads  Time Taken (Sec)
# 0        1          8.817372
# 1        2          8.661842
# 2        3          7.540602
# 3        4          8.727768
# 4        5          8.110349
# 5        6          8.678240
# 6        7          9.096561
# 7        8          8.211291
